# %%
# !pip install langchain
# !pip install openai
# !pip install faiss-cpu
# !pip install langchainhub
# !pip install pdfplumber
# !pip install -U :class:`~langchain-huggingface
# !pip install sentence-transformers
# !pip install langchain langchain-community langchainhub groq
# !pip install langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 48.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 55.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 52.4 MB/s eta 0:00:00
# ...
# /bin/bash: -c: line 1: unexpected EOF while looking for matching ``'
# /bin/bash: -c: line 2: syntax error: unexpected end of file
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 26.2 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders import PyPDFLoader
loader =  PyPDFLoader(r"/kaggle/input/engroreports/DH-3rd-Qaurterly-Report.pdf")
pages = loader.load()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size = 500 , chunk_overlap = 50)
docs = splitter.split_documents(pages)

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

db = FAISS.from_documents(docs , embedding_model)
db.save_local('faiss_index')
# Out:
# /tmp/ipykernel_13/199464084.py:4: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# 2025-04-13 20:12:43.315198: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744575163.560674      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
from langchain_community.vectorstores import FAISS

# Load DB
db = FAISS.load_local(
    "faiss_index",
    embedding_model,
    allow_dangerous_deserialization=True
)


# Run similarity search
query = "What is the company's revenue?"
docs = db.similarity_search(query)

for doc in docs:
    print(doc.page_content)
# Out:
# 2023 unconsolidated ﬁnancial statements.
# SEASONALITY OF OPERATIONS
#
# The principal activity of the Company is to manage investments including in its subsidiaries.  Revenue of the Company
# mainly comprises dividend income which is dependent on the proﬁtability and the decisions of directors and
# shareholders of the subsidiaries regarding the declaration and approval of dividends. Whereas the majority of costs of
# 43
# Associated companies, joint ventures and other related parties
# Purchases and services
# Services rendered  / sale of goods
# Dividends received / receivable
# Dividend paid / payable
# Reimbursements of expenses made by associates and joint ventures
# Reimbursements of expenses made to associates and joint ventures
# Reimbursement of expenses of other related parties
# Donations
# Member Subscription and other fee
# Utilization of overdraft facility
# Loans repaid
# Finance costs
# CONSOLIDATED CONDENSED INTERIM
# STATEMENT OF PROFIT OR LOSS (UN-AUDITED)
# ...

# %%
from langchain_groq import ChatGroq
from langchain.chains import RetrievalQA
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("GROQ_API")

db = FAISS.load_local(
    "faiss_index",
    embedding_model,
    allow_dangerous_deserialization=True
)

llm = ChatGroq(
    groq_api_key = "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",
    model_name="gemma2-9b-it",
    temperature=0.7)

qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=db.as_retriever(),
    chain_type="stuff",
    return_source_documents=True
)

# %%
query = "What is the company's revenue"
result = qa_chain.invoke({"query": query})
print(result["result"])
# Out:
# This document does not say what the company's revenue is.
#
#
# It does mention that the company's revenue mainly comprises dividend income and that Engro Eximp FZE achieved a turnover of USD 397 million this quarter.  However, it doesn't state the company's total revenue.

# %%
from IPython.display import Markdown 
query = "What were the key financial highlights and strategic initiatives mentioned in Engro Corporation's 2024 Annual Report?"
result = qa_chain.invoke({"query": query})
Markdown(result["result"])
# Out:
# The provided text mentions the following financial highlights and strategic initiatives for Engro Corporation in its 2024 Annual Report:
#
# * **Resilient portfolio performance:** Despite adverse conditions affecting key businesses, Engro's portfolio has performed resiliently.
# * **FrieslandCampina Engro Pakistan Limited (FCEPL) performance:**  FCEPL, a significant investment for Engro, faced challenges due to high taxation on the dairy sector. However, the company achieved remarkable growth in its top and bottom line compared to Q3 2023 due to:
#     * **Rigorous cost savings**
#     * **Strategic consumer offerings**
# * **Engro Corporation's overall return:** The company continues to provide significant returns.
#
#
# The text does not provide specific financial numbers or detailed information on other strategic initiatives.

# %%
query = "How is Engro planning to enhance its international footprint, and what role do its subsidiaries play in that strategy according to the 2024 Annual Report?"
result = qa_chain.invoke({"query": query})
Markdown(result["result"])
# Out:
# The provided text does not explain how Engro is planning to enhance its international footprint, nor does it detail the role of its subsidiaries in that strategy.
